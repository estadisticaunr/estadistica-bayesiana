# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot(x, y, ax, col, group, **kwargs):  
    legend = ax.get_legend() or []
    if legend:
        handles = legend.legendHandles
        print(handles)
        labels = [txt.get_text() for txt in legend.get_texts()]
    else:
        handles = []
        labels = []
    hline, = ax.plot(x, y, ls='--', color=col)
    hpatch = ax.fill_between(x, y+10, y-10, color=col, alpha=0.5)

    handles += [(hline, hpatch)]
    labels += [f"group {group}: Mean + interval"]

    ax.legend(handles=handles, labels=labels)
    return legend

# %%
fig, ax = plt.subplots()
x = np.linspace(1, 100, 100)
plot(x, x, ax, "C0", 1)
plot(x, x + 30, ax, "C1", 2)
lg = plot(x, x + 60, ax, "C2", 3)
# Out:
# [<matplotlib.lines.Line2D object at 0x7fa4adff8070>]
# [<matplotlib.lines.Line2D object at 0x7fa4ae002280>, <matplotlib.lines.Line2D object at 0x7fa4ae0027f0>]

# %%
lg.lege
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_28604/2954101235.py in <cell line: 1>()
# ----> 1 lg.get_legend_handler()
#
# TypeError: get_legend_handler() missing 2 required positional arguments: 'legend_handler_map' and 'orig_handle'

# %%
ax.legend().legendHandles
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# []

# %%
handles, labels
# Out:
# ([<matplotlib.lines.Line2D at 0x7fa4ae38feb0>], ['group 1: Mean + interval'])

# %%
def plot(x, y, ax, col, group, **kwargs):
    hline, = ax.plot(x, y, 'k--', color=col)
    hpatch = ax.fill_between(x, y+10, y-10, color=col, alpha=0.5)

    ax.legend([(hline, hpatch)], [f"group {group}: Mean + interval"])

# %%
ax.legend()
